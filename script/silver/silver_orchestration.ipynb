# %% [markdown]
# ## Orchestration Logic

# %%
notebooks = [
    "./crm/silver_crm_customers",
    "./crm/silver_crm_order_items",
    "./crm/silver_crm_orders",
    "./crm/silver_crm_payments",
    "./crm/silver_crm_products"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
