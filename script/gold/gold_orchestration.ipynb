# %% [markdown]
# ## Orchestration Logic

# %%
notebooks = [
    "./gold_dim_products",
    "./gold_fact_sales",
    "./gold_fact_order_items"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
